# %%
import numpy as np
from sklearn.utils import shuffle
#from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
data = pd.read_csv(r'D:\Classes\COMP 490\LeagueChampionRecommender\Tut\ParsedGameData.txt')  #Read data in
samples = data.iloc[:,:data.shape[1]-2] #Split data into samples...
labels = data.iloc[:,data.shape[1]-1:] #And labels
samples = samples.to_numpy()
labels = labels.to_numpy()
samples, labels = shuffle(samples, labels)  #Shuffle samples and labels while keeping them in the same locations relative to eachother

# %%
#scaler = MinMaxScaler(feature_range=(0,1))
#scaled_samples = scaler.fit_transform(samples)
#scaled_labels = scaler.fit_transform(labels)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy

# %%
#physical_devices = tf.config.experimental.list_physical_devices('GPU')
#print("Num GPUs Available: ", len(physical_devices))
#tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
model = Sequential([
    Dense(units=8, input_shape=(len(samples[0]),), activation='relu'),
    Dense(units=2, activation='softmax')  #This creates a neural network with an input layer defined by the
    #shape of the input data and an output layer with two possible outcomes, the value of each being a probability and the
    #sum of both being equal to 1
])
#model.summary()  #Prints a textual representation of the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy']) #Prepare model using given settings
model.fit(x=samples, y=labels, validation_split=0.1, epochs=100, shuffle=True, verbose=2) #Train model
# Out:
# Epoch 1/100
# 28601/28601 - 23s - loss: 0.6905 - accuracy: 0.5281 - val_loss: 0.6876 - val_accuracy: 0.5408
# Epoch 2/100
# 28601/28601 - 16s - loss: 0.6869 - accuracy: 0.5431 - val_loss: 0.6867 - val_accuracy: 0.5455
# Epoch 3/100
# 28601/28601 - 16s - loss: 0.6863 - accuracy: 0.5449 - val_loss: 0.6859 - val_accuracy: 0.5460
# Epoch 4/100
# 28601/28601 - 16s - loss: 0.6855 - accuracy: 0.5458 - val_loss: 0.6852 - val_accuracy: 0.5471
# Epoch 5/100
# 28601/28601 - 16s - loss: 0.6851 - accuracy: 0.5464 - val_loss: 0.6851 - val_accuracy: 0.5474
# Epoch 6/100
# 28601/28601 - 17s - loss: 0.6849 - accuracy: 0.5468 - val_loss: 0.6851 - val_accuracy: 0.5470
# Epoch 7/100
# 28601/28601 - 16s - loss: 0.6847 - accuracy: 0.5472 - val_loss: 0.6850 - val_accuracy: 0.5478
# Epoch 8/100
# 28601/28601 - 17s - loss: 0.6846 - accuracy: 0.5476 - val_loss: 0.6850 - val_accuracy: 0.5467
# Epoch 9/100
# 28601/28601 - 16s - loss: 0.6844 - accuracy: 0.5479 - val_loss: 0.6851 - val_accuracy: 0.5473
# Epoch 10/100
# 28601/28601 - 16s - loss: 0.6843 - accuracy: 0.5484 - val_loss: 0.6850 - val_accuracy: 0.5474
# Epoch 11/100
# 28601/28601 - 17s - loss: 0.6841 - accuracy: 0.5486 - val_loss: 0.6848 - val_accuracy: 0.5478
# Epoch 12/100
# 28601/28601 - 16s - loss: 0.6839 - accuracy: 0.5487 - val_loss: 0.6847 - val_accuracy: 0.5487
# Epoch 13/100
# 28601/28601 - 16s - loss: 0.6836 - accuracy: 0.5492 - val_loss: 0.6846 - val_accuracy: 0.5480
# Epoch 14/100
# 28601/28601 - 17s - loss: 0.6833 - accuracy: 0.5498 - val_loss: 0.6843 - val_accuracy: 0.5484
# Epoch 15/100
# 28601/28601 - 17s - loss: 0.6831 - accuracy: 0.5500 - val_loss: 0.6843 - val_accuracy: 0.5482
# Epoch 16/100
# 28601/28601 - 17s - loss: 0.6829 - accuracy: 0.5505 - val_loss: 0.6841 - val_accuracy: 0.5493
# Epoch 17/100
# 28601/28601 - 17s - loss: 0.6828 - accuracy: 0.5508 - val_loss: 0.6843 - val_accuracy: 0.5473
# Epoch 18/100
# 28601/28601 - 16s - loss: 0.6827 - accuracy: 0.5511 - val_loss: 0.6841 - val_accuracy: 0.5480
# Epoch 19/100
# 28601/28601 - 17s - loss: 0.6826 - accuracy: 0.5518 - val_loss: 0.6842 - val_accuracy: 0.5475
# Epoch 20/100
# 28601/28601 - 17s - loss: 0.6825 - accuracy: 0.5517 - val_loss: 0.6840 - val_accuracy: 0.5484
# Epoch 21/100
# 28601/28601 - 19s - loss: 0.6824 - accuracy: 0.5518 - val_loss: 0.6839 - val_accuracy: 0.5494
# Epoch 22/100
# 28601/28601 - 18s - loss: 0.6823 - accuracy: 0.5524 - val_loss: 0.6838 - val_accuracy: 0.5491
# Epoch 23/100
# 28601/28601 - 16s - loss: 0.6821 - accuracy: 0.5523 - val_loss: 0.6839 - val_accuracy: 0.5496
# Epoch 24/100
# 28601/28601 - 17s - loss: 0.6820 - accuracy: 0.5527 - val_loss: 0.6837 - val_accuracy: 0.5496
# Epoch 25/100
# 28601/28601 - 15s - loss: 0.6820 - accuracy: 0.5530 - val_loss: 0.6836 - val_accuracy: 0.5501
# Epoch 26/100
# 28601/28601 - 15s - loss: 0.6819 - accuracy: 0.5532 - val_loss: 0.6835 - val_accuracy: 0.5502
# Epoch 27/100
# 28601/28601 - 17s - loss: 0.6818 - accuracy: 0.5534 - val_loss: 0.6836 - val_accuracy: 0.5500
# Epoch 28/100
# 28601/28601 - 15s - loss: 0.6817 - accuracy: 0.5534 - val_loss: 0.6835 - val_accuracy: 0.5499
# Epoch 29/100
# 28601/28601 - 15s - loss: 0.6817 - accuracy: 0.5538 - val_loss: 0.6835 - val_accuracy: 0.5514
# Epoch 30/100
# 28601/28601 - 14s - loss: 0.6816 - accuracy: 0.5537 - val_loss: 0.6834 - val_accuracy: 0.5513
# Epoch 31/100
# 28601/28601 - 15s - loss: 0.6815 - accuracy: 0.5536 - val_loss: 0.6835 - val_accuracy: 0.5510
# Epoch 32/100
# 28601/28601 - 17s - loss: 0.6815 - accuracy: 0.5541 - val_loss: 0.6835 - val_accuracy: 0.5502
# Epoch 33/100
# 28601/28601 - 19s - loss: 0.6814 - accuracy: 0.5542 - val_loss: 0.6833 - val_accuracy: 0.5521
# Epoch 34/100
# 28601/28601 - 20s - loss: 0.6813 - accuracy: 0.5542 - val_loss: 0.6833 - val_accuracy: 0.5514
# Epoch 35/100
# 28601/28601 - 16s - loss: 0.6813 - accuracy: 0.5545 - val_loss: 0.6831 - val_accuracy: 0.5513
# Epoch 36/100
# 28601/28601 - 15s - loss: 0.6812 - accuracy: 0.5548 - val_loss: 0.6832 - val_accuracy: 0.5514
# Epoch 37/100
# 28601/28601 - 15s - loss: 0.6812 - accuracy: 0.5549 - val_loss: 0.6831 - val_accuracy: 0.5517
# Epoch 38/100
# 28601/28601 - 15s - loss: 0.6811 - accuracy: 0.5551 - val_loss: 0.6832 - val_accuracy: 0.5503
# Epoch 39/100
# 28601/28601 - 15s - loss: 0.6811 - accuracy: 0.5550 - val_loss: 0.6830 - val_accuracy: 0.5516
# Epoch 40/100
# 28601/28601 - 15s - loss: 0.6811 - accuracy: 0.5554 - val_loss: 0.6830 - val_accuracy: 0.5518
# Epoch 41/100
# 28601/28601 - 15s - loss: 0.6810 - accuracy: 0.5555 - val_loss: 0.6827 - val_accuracy: 0.5515
# Epoch 42/100
# 28601/28601 - 17s - loss: 0.6809 - accuracy: 0.5557 - val_loss: 0.6828 - val_accuracy: 0.5516
# Epoch 43/100
# 28601/28601 - 16s - loss: 0.6809 - accuracy: 0.5557 - val_loss: 0.6827 - val_accuracy: 0.5521
# Epoch 44/100
# 28601/28601 - 17s - loss: 0.6809 - accuracy: 0.5556 - val_loss: 0.6826 - val_accuracy: 0.5512
# Epoch 45/100
# 28601/28601 - 18s - loss: 0.6808 - accuracy: 0.5560 - val_loss: 0.6827 - val_accuracy: 0.5514
# Epoch 46/100
# 28601/28601 - 17s - loss: 0.6807 - accuracy: 0.5561 - val_loss: 0.6827 - val_accuracy: 0.5524
# Epoch 47/100
# 28601/28601 - 18s - loss: 0.6807 - accuracy: 0.5562 - val_loss: 0.6825 - val_accuracy: 0.5522
# Epoch 48/100
# 28601/28601 - 18s - loss: 0.6807 - accuracy: 0.5566 - val_loss: 0.6824 - val_accuracy: 0.5522
# Epoch 49/100
# 28601/28601 - 18s - loss: 0.6806 - accuracy: 0.5565 - val_loss: 0.6826 - val_accuracy: 0.5520
# Epoch 50/100
# 28601/28601 - 20s - loss: 0.6806 - accuracy: 0.5566 - val_loss: 0.6825 - val_accuracy: 0.5514
# Epoch 51/100
# 28601/28601 - 18s - loss: 0.6805 - accuracy: 0.5566 - val_loss: 0.6828 - val_accuracy: 0.5521
# Epoch 52/100
# 28601/28601 - 18s - loss: 0.6805 - accuracy: 0.5568 - val_loss: 0.6824 - val_accuracy: 0.5529
# Epoch 53/100
# 28601/28601 - 18s - loss: 0.6804 - accuracy: 0.5571 - val_loss: 0.6822 - val_accuracy: 0.5530
# Epoch 54/100
# 28601/28601 - 20s - loss: 0.6804 - accuracy: 0.5572 - val_loss: 0.6824 - val_accuracy: 0.5526
# Epoch 55/100
# 28601/28601 - 21s - loss: 0.6803 - accuracy: 0.5572 - val_loss: 0.6823 - val_accuracy: 0.5518
# Epoch 56/100
# 28601/28601 - 21s - loss: 0.6803 - accuracy: 0.5572 - val_loss: 0.6825 - val_accuracy: 0.5519
# Epoch 57/100
# 28601/28601 - 19s - loss: 0.6803 - accuracy: 0.5577 - val_loss: 0.6821 - val_accuracy: 0.5539
# Epoch 58/100
# 28601/28601 - 19s - loss: 0.6802 - accuracy: 0.5572 - val_loss: 0.6819 - val_accuracy: 0.5536
# Epoch 59/100
# 28601/28601 - 19s - loss: 0.6802 - accuracy: 0.5576 - val_loss: 0.6822 - val_accuracy: 0.5535
# Epoch 60/100
# 28601/28601 - 18s - loss: 0.6802 - accuracy: 0.5572 - val_loss: 0.6821 - val_accuracy: 0.5533
# Epoch 61/100
# 28601/28601 - 16s - loss: 0.6801 - accuracy: 0.5579 - val_loss: 0.6821 - val_accuracy: 0.5541
# Epoch 62/100
# 28601/28601 - 16s - loss: 0.6801 - accuracy: 0.5580 - val_loss: 0.6821 - val_accuracy: 0.5538
# Epoch 63/100
# 28601/28601 - 17s - loss: 0.6800 - accuracy: 0.5584 - val_loss: 0.6818 - val_accuracy: 0.5540
# Epoch 64/100
# 28601/28601 - 17s - loss: 0.6800 - accuracy: 0.5580 - val_loss: 0.6819 - val_accuracy: 0.5539
# Epoch 65/100
# 28601/28601 - 17s - loss: 0.6800 - accuracy: 0.5585 - val_loss: 0.6820 - val_accuracy: 0.5553
# Epoch 66/100
# 28601/28601 - 16s - loss: 0.6799 - accuracy: 0.5581 - val_loss: 0.6819 - val_accuracy: 0.5552
# Epoch 67/100
# 28601/28601 - 17s - loss: 0.6799 - accuracy: 0.5581 - val_loss: 0.6820 - val_accuracy: 0.5550
# Epoch 68/100
# 28601/28601 - 17s - loss: 0.6799 - accuracy: 0.5586 - val_loss: 0.6821 - val_accuracy: 0.5538
# Epoch 69/100
# 28601/28601 - 17s - loss: 0.6798 - accuracy: 0.5588 - val_loss: 0.6819 - val_accuracy: 0.5552
# Epoch 70/100
# 28601/28601 - 15s - loss: 0.6798 - accuracy: 0.5586 - val_loss: 0.6819 - val_accuracy: 0.5549
# Epoch 71/100
# 28601/28601 - 15s - loss: 0.6798 - accuracy: 0.5587 - val_loss: 0.6821 - val_accuracy: 0.5535
# Epoch 72/100
# 28601/28601 - 15s - loss: 0.6798 - accuracy: 0.5588 - val_loss: 0.6818 - val_accuracy: 0.5547
# Epoch 73/100
# 28601/28601 - 15s - loss: 0.6797 - accuracy: 0.5591 - val_loss: 0.6819 - val_accuracy: 0.5537
# Epoch 74/100
# 28601/28601 - 15s - loss: 0.6797 - accuracy: 0.5592 - val_loss: 0.6818 - val_accuracy: 0.5539
# Epoch 75/100
# 28601/28601 - 15s - loss: 0.6797 - accuracy: 0.5591 - val_loss: 0.6819 - val_accuracy: 0.5541
# Epoch 76/100
# 28601/28601 - 15s - loss: 0.6796 - accuracy: 0.5590 - val_loss: 0.6818 - val_accuracy: 0.5546
# Epoch 77/100
# 28601/28601 - 16s - loss: 0.6796 - accuracy: 0.5597 - val_loss: 0.6817 - val_accuracy: 0.5551
# Epoch 78/100
# 28601/28601 - 15s - loss: 0.6796 - accuracy: 0.5594 - val_loss: 0.6821 - val_accuracy: 0.5545
# Epoch 79/100
# 28601/28601 - 15s - loss: 0.6796 - accuracy: 0.5594 - val_loss: 0.6818 - val_accuracy: 0.5540
# Epoch 80/100
# 28601/28601 - 15s - loss: 0.6795 - accuracy: 0.5596 - val_loss: 0.6817 - val_accuracy: 0.5545
# Epoch 81/100
# 28601/28601 - 16s - loss: 0.6795 - accuracy: 0.5594 - val_loss: 0.6817 - val_accuracy: 0.5555
# Epoch 82/100
# 28601/28601 - 17s - loss: 0.6795 - accuracy: 0.5598 - val_loss: 0.6816 - val_accuracy: 0.5554
# Epoch 83/100
# 28601/28601 - 17s - loss: 0.6794 - accuracy: 0.5598 - val_loss: 0.6820 - val_accuracy: 0.5542
# Epoch 84/100
# 28601/28601 - 17s - loss: 0.6795 - accuracy: 0.5596 - val_loss: 0.6818 - val_accuracy: 0.5552
# Epoch 85/100
# 28601/28601 - 16s - loss: 0.6795 - accuracy: 0.5600 - val_loss: 0.6817 - val_accuracy: 0.5561
# Epoch 86/100
# 28601/28601 - 18s - loss: 0.6794 - accuracy: 0.5596 - val_loss: 0.6818 - val_accuracy: 0.5549
# Epoch 87/100
# 28601/28601 - 15s - loss: 0.6794 - accuracy: 0.5598 - val_loss: 0.6820 - val_accuracy: 0.5535
# Epoch 88/100
# 28601/28601 - 15s - loss: 0.6794 - accuracy: 0.5598 - val_loss: 0.6820 - val_accuracy: 0.5540
# Epoch 89/100
# 28601/28601 - 17s - loss: 0.6794 - accuracy: 0.5599 - val_loss: 0.6819 - val_accuracy: 0.5564
# Epoch 90/100
# 28601/28601 - 16s - loss: 0.6794 - accuracy: 0.5598 - val_loss: 0.6818 - val_accuracy: 0.5561
# Epoch 91/100
# 28601/28601 - 15s - loss: 0.6794 - accuracy: 0.5599 - val_loss: 0.6820 - val_accuracy: 0.5550
# Epoch 92/100
# 28601/28601 - 15s - loss: 0.6794 - accuracy: 0.5599 - val_loss: 0.6816 - val_accuracy: 0.5558
# Epoch 93/100
# 28601/28601 - 14s - loss: 0.6793 - accuracy: 0.5600 - val_loss: 0.6818 - val_accuracy: 0.5552
# Epoch 94/100
# 28601/28601 - 15s - loss: 0.6793 - accuracy: 0.5599 - val_loss: 0.6817 - val_accuracy: 0.5559
# Epoch 95/100
# 28601/28601 - 15s - loss: 0.6793 - accuracy: 0.5597 - val_loss: 0.6819 - val_accuracy: 0.5551
# Epoch 96/100
# 28601/28601 - 15s - loss: 0.6793 - accuracy: 0.5598 - val_loss: 0.6816 - val_accuracy: 0.5563
# Epoch 97/100
# 28601/28601 - 15s - loss: 0.6793 - accuracy: 0.5600 - val_loss: 0.6817 - val_accuracy: 0.5561
# Epoch 98/100
# 28601/28601 - 15s - loss: 0.6793 - accuracy: 0.5600 - val_loss: 0.6818 - val_accuracy: 0.5558
# Epoch 99/100
# 28601/28601 - 16s - loss: 0.6793 - accuracy: 0.5600 - val_loss: 0.6816 - val_accuracy: 0.5565
# Epoch 100/100
# 28601/28601 - 15s - loss: 0.6793 - accuracy: 0.5598 - val_loss: 0.6818 - val_accuracy: 0.5567

# %%
model.save('models/OracleLensTestModel.h5')
